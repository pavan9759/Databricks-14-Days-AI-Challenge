# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.bronze.events
USING DELTA
AS
SELECT * FROM ecommerce.bronze.ecommerce_data;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.silver.events
USING DELTA
AS
SELECT * FROM ecommerce.bronze.events;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.gold.events
USING DELTA
AS
SELECT * FROM ecommerce.silver.events;

# %%
# %sql
CREATE OR REPLACE VIEW ecommerce.bronze.a AS
SELECT * FROM ecommerce.bronze.ecommerce_data;

# %%
# %sql
SELECT * FROM ecommerce.bronze.a;
